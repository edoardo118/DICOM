# %%
import inspect
import fastai.medical.imaging

for name, obj in inspect.getmembers(fastai.medical.imaging):
    if inspect.isclass(obj):
        print(obj)
# Out:
# <class 'fastai.metrics.AccumMetric'>
# <class 'fastai.callback.hook.ActivationStats'>
# <class 'fastai.layers.AdaptiveConcatPool1d'>
# <class 'fastai.layers.AdaptiveConcatPool2d'>
# <class 'fastai.vision.core.AddMaskCodes'>
# <class 'fastai.vision.augment.AffineCoordTfm'>
# <class 'fastai.torch_core.ArrayBase'>
# <class 'fastai.torch_core.ArrayImage'>
# <class 'fastai.torch_core.ArrayImageBW'>
# <class 'fastai.torch_core.ArrayImageBase'>
# <class 'fastai.torch_core.ArrayMask'>
# <class 'fastcore.basics.AttrDict'>
# <class 'fastai.data.transforms.AttrGetter'>
# <class 'fastcore.meta.AutoInit'>
# <class 'fastai.learner.AvgLoss'>
# <class 'fastai.learner.AvgMetric'>
# <class 'fastai.learner.AvgSmoothLoss'>
# <class 'fastai.vision.core.BBoxLabeler'>
# <class 'fastai.losses.BCEWithLogitsLossFlat'>
# <class 'fastai.losses.BaseLoss'>
# <class 'fastai.layers.BatchNorm1dFlat'>
# <class 'torch.utils.data.sampler.BatchSampler'>
# <class 'fastai.callback.training.BnFreeze'>
# ...
